# %%
import os
import requests
import tweepy
import matplotlib.pyplot as plt
from IPython.display import display
# tweepy GitHub: https://github.com/tweepy/tweepy
# tweepy Document: http://tweepy.readthedocs.io/en/v3.5.0/index.html

# %%
consumer_key = "UZ07BQX9FRvXK6f0pkRPkQr0D"
consumer_secret = "Dw7Dl7w0y0Je5YO07DwjukTliQMazE0sxKfZUnc5PHXovoZjXy"
access_token = "893758559548080128-4OsFtaNZAZ9UeXqctWeNpC4uuK9nrgL"
access_token_secret = "o8lS3n0D0qNJp8ij4ky4uA2AuRW3gKenhaz2zLjoGjF8Q"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline(count=20)
for tweet in tweets:
    print(tweet.text)
    print("====")
# Out:
# RT @spongenami102: 花巻の旅つかれたね〜
#
# 以外にすぐ着いてあれ？こんなもん？って感じだったｗｗ
#
# マルカンソフト食べれたし
# ブルーベリー狩りも行けてめっちゃ幸せだった！！！
#
# ちゃりで旅するのなかなかいいね♡
# かのんありがとう😝😝😝
#
# @nonon1777…
# ====
# RT @hiryu10969: じゅんや家version https://t.co/MdOSpvu7PF
# ====
# RT @misa7260: Mashu is bae 💕❤️
# Cosplayer/Me @misa7260
# Photo/Zuo Fung https://t.co/5v2KvGCMUb
# ====
# お腹空いたコンビニいって
# タラタラ買ってこようかな😑😑
# ====
# 中学の合唱コン思い出す♡みんな西中であたしだけ四砂だけど♡爆 https://t.co/yKlRxJHyRh
# ====
# RT @BAZOOKA_BS241: 第12回高校生RAP選手権in幕張 出場者決定💨✨
# #高ラ #出場者決定 #BAZOOKA
# 会場で応援しよう！🎤
# https://t.co/WsQttZ1Xxe https://t.co/LUR0RIDcfh
# ====
# はぁぁあ😍 https://t.co/GdEtMqFpzD
# ====
# ________________
# 数えきれないほど
# たーーーーーーーーーーっくさん
# 写真撮ってきたけど
# 1番のお気に入り
# Photo📸
# 可… https://t.co/zw87aB1zeg
# ====
# RT @in_nba: 巧みなアシスト、サウスポーショットを披露する、オバマ前大統領。こんなにバスケが上手い大統領見たことない。
# via @InstantRHIplay
#  https://t.co/9WUq2CVUaL
# ====
# @1doZt1II3IYMGPE 画質の悪さにご注意
# ====
# 大好きな親友❤️→@1doZt1II3IYMGPE
#
# 18歳おめでとう。
# みるとの写真はどんなに長い動画でも収まりきらないくらいあるから、
# 1分45秒でまとめたから見てねん😍
#
# ...

# %%
tweets[0]._json
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Aug 07 21:39:01 +0000 2017',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 3337202358,
#     'id_str': '3337202358',
#     'indices': [3, 17],
#     'name': 'ෆ  ち ぇ る  ෆ',
#     'screen_name': 'spongenami102'},
#    {'id': 3243710406,
#     'id_str': '3243710406',
#     'indices': [128, 138],
#     'name': 'かのん',
#     'screen_name': 'nonon1777'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 894674265768738816,
#  'id_str': '894674265768738816',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'ja',
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
# ...

# %%
print(tweets[0]._json.keys())
print(tweets[0]._json["id"])
print(tweets[0]._json["text"])
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])
# 894674265768738816
# RT @spongenami102: 花巻の旅つかれたね〜
#
# 以外にすぐ着いてあれ？こんなもん？って感じだったｗｗ
#
# マルカンソフト食べれたし
# ブルーベリー狩りも行けてめっちゃ幸せだった！！！
#
# ちゃりで旅するのなかなかいいね♡
# かのんありがとう😝😝😝
#
# @nonon1777…

# %%
tweets = api.home_timeline(count=20)
len(tweets)
# Out:
# 18

# %%
# tweets[0]._json["entities"]["media"][0][]

# リツイートのやつ
display(tweets[2]._json["entities"])
print("=======")
display(tweets[2]._json["extended_entities"])
# Out:
# {'hashtags': [],
#  'media': [{'display_url': 'pic.twitter.com/9T22dUasf7',
#    'expanded_url': 'https://twitter.com/X2X__X6X/status/894851679836700676/photo/1',
#    'id': 894851654477987842,
#    'id_str': '894851654477987842',
#    'indices': [19, 42],
#    'media_url': 'http://pbs.twimg.com/media/DGsm1q_UwAIz0H8.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DGsm1q_UwAIz0H8.jpg',
#    'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1536},
#     'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#     'small': {'h': 680, 'resize': 'fit', 'w': 510},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'source_status_id': 894851679836700676,
#    'source_status_id_str': '894851679836700676',
#    'source_user_id': 746822558301855744,
#    'source_user_id_str': '746822558301855744',
#    'type': 'photo',
#    'url': 'https://t.co/9T22dUasf7'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 746822558301855744,
# ...

# %%
display(tweets[14]._json["extended_entities"])
# Out:
# {'media': [{'display_url': 'pic.twitter.com/JvU1kAS3bn',
#    'expanded_url': 'https://twitter.com/Black_rin5/status/894855868973367296/photo/1',
#    'id': 894855851650891776,
#    'id_str': '894855851650891776',
#    'indices': [89, 112],
#    'media_url': 'http://pbs.twimg.com/media/DGsqp-rUwAA-9oC.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DGsqp-rUwAA-9oC.jpg',
#    'sizes': {'large': {'h': 1432, 'resize': 'fit', 'w': 1441},
#     'medium': {'h': 1193, 'resize': 'fit', 'w': 1200},
#     'small': {'h': 676, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'source_status_id': 894855868973367296,
#    'source_status_id_str': '894855868973367296',
#    'source_user_id': 893024646668341250,
#    'source_user_id_str': '893024646668341250',
#    'type': 'photo',
#    'url': 'https://t.co/JvU1kAS3bn'},
#   {'display_url': 'pic.twitter.com/JvU1kAS3bn',
# ...

# %%
tweets[11]._json
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Aug 07 17:12:21 +0000 2017',
#  'entities': {'hashtags': [],
#   'media': [{'display_url': 'pic.twitter.com/LLaSSnljF9',
#     'expanded_url': 'https://twitter.com/manatmnt/status/894607153637412864/photo/1',
#     'id': 894607123866206208,
#     'id_str': '894607123866206208',
#     'indices': [10, 33],
#     'media_url': 'http://pbs.twimg.com/media/DGpIcHeUQAAmSoc.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DGpIcHeUQAAmSoc.jpg',
#     'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1536},
#      'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#      'small': {'h': 680, 'resize': 'fit', 'w': 510},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'type': 'photo',
#     'url': 'https://t.co/LLaSSnljF9'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/LLaSSnljF9',
# ...

# %%
image = requests.get(media_url).content # 画像を取得
extension = os.path.splitext(media_url)[1] # urlを分割して拡張子を取得
image_path = os.path.join("..", "data", "sample"+extension)
f = open(image_path, "wb")
f.write(image)
# Out:
# 183460

# %%
! cat ../../memo.txt
# Out:
# access token
# 2519317482.7fb02fc.e17e588ebef24e128f964561e1e92be9
#
# client id
# 7fb02fc3e0bd44d488535401e42bf600
#
#
# [twitter api]
# Consumer Key (API Key): UZ07BQX9FRvXK6f0pkRPkQr0D
# Consumer Secret (API Secret): Dw7Dl7w0y0Je5YO07DwjukTliQMazE0sxKfZUnc5PHXovoZjXy
# Access Level: Read and write (modify app permissions)
# Owner: inakanotamii
# Owner ID: 893758559548080128
#
# Access Token: 893758559548080128-4OsFtaNZAZ9UeXqctWeNpC4uuK9nrgL
# Access Token Secret: o8lS3n0D0qNJp8ij4ky4uA2AuRW3gKenhaz2zLjoGjF8Q
# Access Level: Read and write
# Owner: inakanotamii
# Owner ID: 893758559548080128
